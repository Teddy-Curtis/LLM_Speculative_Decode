# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
x = np.linspace(0, 2*np.pi, 500)
y = np.sin(x)

plt.plot(x, y)

# %%
y = np.sin(x * np.cos(x))/np.cos(x * np.sin(x))

plt.plot(x, y)
plt.yscale('log')
